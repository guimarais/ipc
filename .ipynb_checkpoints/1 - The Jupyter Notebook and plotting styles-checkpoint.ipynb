# %%
a=1
b=2
a+b
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-5,5,0.1)
y = np.sin(x)

# %%
plt.plot(x,y,label='sin')
plt.legend()
plt.show()

# %%
# %matplotlib notebook
#inline
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(-5,5,0.1)
y = np.sin(x)
plt.plot(x,y,label='sin')
plt.show()
#remember to close figure
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Simple text goes here

# %% [markdown]
# # Heading 1
# # Heading 2
# ## Heading 2.1
# ### Heading 2.1.1
# #### Heading 2.1.1.1 all the way to 6

# %% [markdown]
# 1. Make a list
# 2. With the entries
#     3. Organized
#     4. As you
#         5. Want
#         6. Oops
#
#
# * Well
# * Numbers
#     * Are not exclusive
#     * To the lists
#
# Go to [Jupyter Notebook](http://jupyter.org/) for more info!

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# ```python
# print "Hello World"
# ```

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  |table |

# %% [markdown]
# Adds an image from the local notebook directory.
# <img src="Files/rflspec_33437.png" />

# %% [markdown]
# Thanks to F. da Silva
# <video width="800" height="500" controls src="Files/ims_V-band_50GHz.m4v" />

# %% [markdown]
# And so many __many__ other _functionalities_, like *__Magics__*:

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
ll #or probably %cd for windows users...
# Out:
# total 1464
# -rw-r--r-- 1 guimas 113307 Aug 21 12:46 1 - The Jupyter Notebook and plotting styles.ipynb
# -rw-r--r-- 1 guimas 185578 Aug 21 12:41 2 - Differentiation and Integration.ipynb
# -rw-r--r-- 1 guimas 455802 Aug 21 12:41 3 - Interpolation.ipynb
# -rw-r--r-- 1 guimas 279980 Aug 21 12:41 4 - Curve fitting.ipynb
# -rw-r--r-- 1 guimas 105910 Aug 21 12:41 5 - Data sets with pandas.ipynb
# -rw-r--r-- 1 guimas 330166 Aug 21 12:41 Appendix A - Signal Processing.ipynb
# drwxr-xr-x 2 guimas   4096 Aug 21 12:46 Files/
# -rw-r--r-- 1 guimas   2803 Aug 21 12:41 Intro to Intermediate classes.ipynb
# drwxr-xr-x 3 guimas   4096 Aug 21 12:41 Project/
# -rw-r--r-- 1 guimas     37 Aug 21 12:41 README.md

# %% [markdown]
# And you can __Cell Magics__, that allow to virtually run wahtever you want (next example for unix users only):

# %%
# %%bash
#
# grep *.ipynb -e "import "
# Out:
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import matplotlib.pyplot as plt\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import numpy as np"
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import matplotlib.pyplot as plt\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import numpy as np\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import numpy as np\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import numpy as np\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"grep *.ipynb -e \\\"import \\\"\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"from IPython.html import widgets as wd\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import numpy as np\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import numpy as np\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import numpy as np\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import matplotlib as mpl\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "0 - The Jupyter Notebook and plotting styles.ipynb:    \"import webbrowser\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "1 - Integration and quadratures.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "1 - Integration and quadratures.ipynb:    \"import numpy as np\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "1 - Integration and quadratures.ipynb:    \"from scipy.integrate import *\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "1 - Integration and quadratures.ipynb:    \"from mpl_toolkits.mplot3d import Axes3D\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "1 - Integration and quadratures.ipynb:    \"from mpl_toolkits.mplot3d import Axes3D\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "1 - Integration and quadratures.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "1 - Integration and quadratures.ipynb:    \"import numpy as np\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "2 - Interpolation.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "2 - Interpolation.ipynb:    \"from scipy import interpolate\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "2 - Interpolation.ipynb:    \"import numpy as np\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "2 - Interpolation.ipynb:    \"from scipy.interpolate import CubicSpline\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "3 - Curve fitting.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "3 - Curve fitting.ipynb:    \"import numpy as np\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "3 - Curve fitting.ipynb:    \"from scipy.optimize import *\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"import pandas as pd\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"from pandas import DataFrame\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"import numpy as np\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"from IPython.display import Image\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"from IPython.core.display import HTML \\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"from IPython.display import YouTubeVideo\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"import webbrowser\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "4 - Data sets with pandas.ipynb:    \"import matplotlib\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "Appendix A - Signal Processing.ipynb:    \"import numpy as np\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "Appendix A - Signal Processing.ipynb:    \"import matplotlib.pyplot as plt\\n\",\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "Appendix A - Signal Processing.ipynb:    \"from scipy import signal\"\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:      "Appendix A - Signal Processing.ipynb:    \"import webbrowser\\n\",\n"
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "grep *.ipynb -e \"import \""
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "from IPython.html import widgets as wd\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import numpy as np\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import matplotlib.pyplot as plt\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import matplotlib.pyplot as plt\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import numpy as np"
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import matplotlib.pyplot as plt\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import numpy as np\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import matplotlib as mpl\n",
# 1 - The Jupyter Notebook and plotting styles.ipynb:    "import webbrowser\n",
# 2 - Differentiation and Integration.ipynb:    "import matplotlib.pyplot as plt\n",
# 2 - Differentiation and Integration.ipynb:    "import numpy as np"
# 2 - Differentiation and Integration.ipynb:    "import sympy as sp\n",
# 2 - Differentiation and Integration.ipynb:    "from scipy.misc import derivative"
# 2 - Differentiation and Integration.ipynb:    "import numpy as np\n",
# 2 - Differentiation and Integration.ipynb:    "from scipy.integrate import odeint\n",
# 2 - Differentiation and Integration.ipynb:    "import matplotlib.pyplot as plt"
# 2 - Differentiation and Integration.ipynb:    "import matplotlib.pyplot as plt\n",
# 2 - Differentiation and Integration.ipynb:    "import numpy as np\n",
# 2 - Differentiation and Integration.ipynb:    "from scipy.integrate import *"
# 2 - Differentiation and Integration.ipynb:    "from mpl_toolkits.mplot3d import Axes3D\n",
# 2 - Differentiation and Integration.ipynb:    "from mpl_toolkits.mplot3d import Axes3D\n",
# 2 - Differentiation and Integration.ipynb:    "import matplotlib.pyplot as plt\n",
# 2 - Differentiation and Integration.ipynb:    "import numpy as np\n",
# 3 - Interpolation.ipynb:    "import matplotlib.pyplot as plt\n",
# 3 - Interpolation.ipynb:    "from scipy import interpolate\n",
# 3 - Interpolation.ipynb:    "import numpy as np"
# 3 - Interpolation.ipynb:    "from scipy.interpolate import CubicSpline"
# 4 - Curve fitting.ipynb:    "import matplotlib.pyplot as plt\n",
# 4 - Curve fitting.ipynb:    "import numpy as np"
# 4 - Curve fitting.ipynb:    "from scipy.optimize import *"
# 5 - Data sets with pandas.ipynb:    "import pandas as pd\n",
# 5 - Data sets with pandas.ipynb:    "from pandas import DataFrame\n",
# 5 - Data sets with pandas.ipynb:    "import numpy as np"
# 5 - Data sets with pandas.ipynb:    "import matplotlib.pyplot as plt\n",
# 5 - Data sets with pandas.ipynb:    "from IPython.display import Image\n",
# 5 - Data sets with pandas.ipynb:    "from IPython.core.display import HTML \n",
# 5 - Data sets with pandas.ipynb:    "from IPython.display import YouTubeVideo\n",
# 5 - Data sets with pandas.ipynb:    "import webbrowser\n",
# 5 - Data sets with pandas.ipynb:    "import matplotlib.pyplot as plt\n",
# 5 - Data sets with pandas.ipynb:    "import matplotlib\n",
# Appendix A - Signal Processing.ipynb:    "import numpy as np\n",
# Appendix A - Signal Processing.ipynb:    "import matplotlib.pyplot as plt\n",
# Appendix A - Signal Processing.ipynb:    "from scipy import signal"
# Appendix A - Signal Processing.ipynb:    "import webbrowser\n",
# Intro to Intermediate classes.ipynb:    "import IPython\n",

# %% [markdown]
# You can even produce shareable GUIs, thanks to the widgets library:

# %%
# %matplotlib inline
import ipywidgets as wd
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0.1, 1.0, 0.01)

def pltsin(f):
    plt.plot(t, np.sin(2.0*np.pi*f*t))
    plt.show()
    
wd.interact(pltsin, f=(1, 10, 0.1))
# Out:
# <function __main__.pltsin>

# %% [markdown]
# # Introduction to plotting styles
#
# A simple approach to the many functionalities of matplotlib.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-5,5,0.01)
y = np.sin(x)

# %%
# %matplotlib inline
def plot_test():
    plt.plot(x,y, label="sin(x)")
    plt.xlabel("X axis")
    plt.ylabel("Y axis")
    plt.title("A simple function")
    plt.legend()
    plt.show()
    
plot_test()

# %%
print plt.style.available

# %%
plt.style.use('ggplot')
plot_test()

# %%
plt.style.use('seaborn-poster')
plot_test()

# %%
plt.style.use('default')
plot_test()

# %%
#Reset everything
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

x = np.arange(-5,5,0.01)
y = np.sin(x)

plt.plot(x,y)
plt.show()

# %%
#Run twice to show that styles must be set before plotting
plt.plot(x,y)
mpl.rcParams['lines.linewidth'] = 5
mpl.rcParams['lines.linestyle'] = '-.'
mpl.rcParams['font.size'] = 16
plt.show()

# %%
#Or use by group
mpl.rc('lines', linewidth=5, linestyle='--')
mpl.rc('font', size=16)
#Not covered in previous lesson because standard way of doing it is... well... dumb...
mpl.rc('xtick', labelsize=26)
mpl.rc('ytick', labelsize=6)
#Last change stands
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('A function')
plt.legend(loc='lower left', fontsize=12)
plt.plot(x,y, label='sin(x)')
plt.show()

# %%
plt.figure(figsize=(3.5,3))
#Or use by group
mpl.rc('lines', linewidth=4, linestyle='--')
mpl.rc('font', size=12)
#Not covered in previous lesson because standard way of doing it is... well... dumb...
mpl.rc('xtick', labelsize=9)
mpl.rc('ytick', labelsize=9)
mpl.rc('axes', labelsize=10)
#Last change stands
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('A function')
plt.plot(x,y, label='sin(x)')
plt.legend(loc='lower right', fontsize=25)
plt.show()

# %%
import webbrowser
url = 'https://matplotlib.org/users/customizing.html'
webbrowser.open_new_tab(url)
